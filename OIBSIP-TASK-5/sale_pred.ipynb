# %% [markdown]
# # SALES PREDICTION USING PYTHON

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("archive (3)/Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df=df.iloc[:,1:]

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(df,kind="reg");

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
X=df[["TV","Radio","Newspaper"]]
y=df["Sales"]

# %%
X=df[["TV","Radio","Newspaper"]]
y=df["Sales"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_pred_linear = linear_reg.predict(X_test)

mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)

print("Multilinear Regression:")
print("Mean Squared Error:", mse_linear)
print("R2 Score:", r2_linear)
# Out:
# Multilinear Regression:
# Mean Squared Error: 4.012497522917098
# R2 Score: 0.8576396745320893

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred_svr = svr.predict(X_test)

mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)

print("Support Vector Regression:")
print("Mean Squared Error:", mse_svr)
print("R2 Score:", r2_svr)
# Out:
# Support Vector Regression:
# Mean Squared Error: 4.456599302892299
# R2 Score: 0.8418832850073463

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = decision_tree.predict(X_test)

mse_dt = mean_squared_error(y_test, y_pred_dt)
r2_dt = r2_score(y_test, y_pred_dt)

print("Decision Tree Regression:")
print("Mean Squared Error:", mse_dt)
print("R2 Score:", r2_dt)
# Out:
# Decision Tree Regression:
# Mean Squared Error: 2.274199999999999
# R2 Score: 0.9193131334461857

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest = RandomForestRegressor()
random_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = random_forest.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest Regression:")
print("Mean Squared Error:", mse_rf)
print("R2 Score:", r2_rf)
# Out:
# Random Forest Regression:
# Mean Squared Error: 0.8741526999999983
# R2 Score: 0.9689857346528202

# %% [markdown]
# Result:
#
#
#
#
# Random Forest performed the best among all other models
